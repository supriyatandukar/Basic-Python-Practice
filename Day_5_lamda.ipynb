# %% [markdown]
# ## 4. Lambda Functions (Anonymous Functions)
#
# Python allows you to create small, unnamed functions using the `lambda` keyword. These are useful for short operations where defining a full function with `def` feels overly verbose.
#
# **Syntax:**
# `lambda arguments: expression`
#
# *   `lambda`: Keyword.
# *   `arguments`: Comma-separated arguments
# *   `expression`: A single expression whose result is implicitly returned. Lambda functions cannot contain multiple statements or complex logic.
#
# They are often used in places where a function object is required, like arguments to `sorted()`, `map()`, `filter()`.

# %%
#parameter, colon, return k garne vanera, ani func call garne
#yesma chaui func define garirakhnu pardaina

# %%
double = lambda x,y: x * y
print(double(5,6))

# #equivalent to function
# def double(x,y):
#     return x * y
# Out:
# 30

# %%
def sum(a,b): return a+b
sum(5,6)
# Out:
# 11

# %%
#yo chai lambda rakhera
add_lambda = lambda a, b: a + b
result = add_lambda(10, 5)
print(f"Result from lambda: {result}")

#Tala ko chai func definee garera garya
def add_def(a, b):
  return a + b
add_def(10,5)
# Out:
# Result from lambda: 15
# 15

# %%
pairs = [(1,3), (4,4), (2,1), (4,5), (3,2), (4,6), (4,5)]

zero_index = sorted(pairs, key=lambda x: x[0])
print(f"Sorted by second element: {zero_index}")
# Out:
# Sorted by second element: [(1, 3), (2, 1), (3, 2), (4, 4), (4, 5), (4, 6), (4, 5)]

# %%
zero_index
# Out:
# [(1, 3), (2, 1), (3, 2), (4, 4), (4, 5), (4, 6), (4, 5)]

# %%
type(zero_index)
# Out:
# list

# %%
zero_index[2] #list bata 3rd ko tuple leko
# Out:
# (3, 2)

# %%
type(new)
# Out:
# tuple

# %%
new = zero_index[2] #feri tuple nai naya var deko

# %%
new[0] #ani tyo tuple bata first ko index lekhyaa
# Out:
# 3

# %%
#yesari ni garna payo
new = sorted_pairs[2][0] #list vitra ani index

# %%
new
# Out:
# 1

# %%
one_index = sorted(sorted_pairs, key=lambda x: x[1])
print(one_index)
# Out:
# [(2, 1), (3, 2), (1, 3), (4, 4), (4, 5), (4, 5), (4, 6)]

# %%
#one_index nai ho
pairs = [(1,3), (4,4), (2,1), (4,5), (3,2), (4,6), (4,5)]

sorted_pairs = sorted(pairs, key=lambda x: x[1])
print(f"Sorted by second element: {sorted_pairs}")
# Out:
# Sorted by second element: [(2, 1), (3, 2), (1, 3), (4, 4), (4, 5), (4, 5), (4, 6)]

# %%
#sorted
pairs = [(1, 'one'), (3, 'three'), (2, 'two'), (2, 'Two')]
sorted_pairs = sorted(pairs, key=lambda x: x[1])
print(sorted_pairs)
# Out:
# [(2, 'Two'), (1, 'one'), (3, 'three'), (2, 'two')]

# %%
#map
numbers = [1,2,3,4]
squared = list(map(lambda x: x * 2, numbers))  #map layena vane for loop le call garne ani vitra lambda func call garne, yesko garda lmo process huna janxa so map is used
print(squared)
# Out:
# [2, 4, 6, 8]

# %%
nums = [1,2,3,4,5,6]
evens = list(filter(lambda x: x % 2 == 0, nums))
print(evens)
# Out:
# [2, 4, 6]

# %%
#for x in numbers
numbers = [1,2,3,4, 5]
squared = (map(lambda x: x ** 2, numbers))
print(list(squared))
# Out:
# [1, 4, 9, 16, 25]

# %%
type(squared)
# Out:
# map

# %%
dir(numbers) # mathi ko hamle deko numbers ma k k garna milxa vanera herna milxa, method haru ho, for eg, .append, clear, et garna milyo, yo kura chai use garna milyo
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
help(squared) #yo ni same mathi jastai k garna milxa vanera herne ho
# Out:
# Help on map object:
#
# class map(object)
#  |  map(function, iterable, /, *iterables)
#  |
#  |  Make an iterator that computes the function using arguments from
#  |  each of the iterables.  Stops when the shortest iterable is exhausted.
#  |
#  |  Methods defined here:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  __reduce__(self, /)
#  |      Return state information for pickling.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs)
#  |      Create and return a new object.  See help(type) for accurate signature.

# %% [markdown]
# ##### model banayo vane k k garna milxa vanera herna

# %% [markdown]
# # Operations on String

# %%
#mutable
#ordered

# %%
dir(str) #same as text as text is string
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
text = """He suggested Trudeau was the problem
@The Daily Digest
On May 16th, an interesting interview with the former US Ambassador to Canada under Joe Biden, David L. Cohen, claimed Canada’s responses to Donald Trump’s tariffs and sovereignty threats were an overreaction caused by the President's strained relationship with Justin Trudeau.
"""

#yo string xa re, aba yesma k k herna milxa

# %%
dir(text)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
text.isprintable()
# Out:
# False

# %%
text.capitalize()
# Out:
# "He suggested trudeau was the problem\n@the daily digest\non may 16th, an interesting interview with the former us ambassador to canada under joe biden, david l. cohen, claimed canada’s responses to donald trump’s tariffs and sovereignty threats were an overreaction caused by the president's strained relationship with justin trudeau.\n"

# %%
text.casefold()
# Out:
# "he suggested trudeau was the problem\n@the daily digest\non may 16th, an interesting interview with the former us ambassador to canada under joe biden, david l. cohen, claimed canada’s responses to donald trump’s tariffs and sovereignty threats were an overreaction caused by the president's strained relationship with justin trudeau.\n"

# %%
replaced = text.replace("a", "b")
print(replaced)
# Out:
# He suggested Trudebu wbs the problem
# @The Dbily Digest
# On Mby 16th, bn interesting interview with the former US Ambbssbdor to Cbnbdb under Joe Biden, Dbvid L. Cohen, clbimed Cbnbdb’s responses to Donbld Trump’s tbriffs bnd sovereignty threbts were bn overrebction cbused by the President's strbined relbtionship with Justin Trudebu.

# %%
count_a = replaced.count('b')
count_a
# Out:
# 28

# %%
new_data = text.swapcase()
new_data
# Out:
# "hE SUGGESTED tRUDEAU WAS THE PROBLEM\n@tHE dAILY dIGEST\noN mAY 16TH, AN INTERESTING INTERVIEW WITH THE FORMER us aMBASSADOR TO cANADA UNDER jOE bIDEN, dAVID l. cOHEN, CLAIMED cANADA’S RESPONSES TO dONALD tRUMP’S TARIFFS AND SOVEREIGNTY THREATS WERE AN OVERREACTION CAUSED BY THE pRESIDENT'S STRAINED RELATIONSHIP WITH jUSTIN tRUDEAU.\n"

# %%
text.count('a')
# Out:
# 25

# %%
text.strip()  #unwanted space hataune kaam garxa
# Out:
# "He suggested Trudeau was the problem\n@The Daily Digest\nOn May 16th, an interesting interview with the former US Ambassador to Canada under Joe Biden, David L. Cohen, claimed Canada’s responses to Donald Trump’s tariffs and sovereignty threats were an overreaction caused by the President's strained relationship with Justin Trudeau."

# %%
text.title()
# Out:
# "He Suggested Trudeau Was The Problem\n@The Daily Digest\nOn May 16Th, An Interesting Interview With The Former Us Ambassador To Canada Under Joe Biden, David L. Cohen, Claimed Canada’S Responses To Donald Trump’S Tariffs And Sovereignty Threats Were An Overreaction Caused By The President'S Strained Relationship With Justin Trudeau.\n"

# %%
text.split()
# Out:
# ['He',
#  'suggested',
#  'Trudeau',
#  'was',
#  'the',
#  'problem',
#  '@The',
#  'Daily',
#  'Digest',
#  'On',
#  'May',
#  '16th,',
#  'an',
#  'interesting',
#  'interview',
#  'with',
#  'the',
#  'former',
#  'US',
#  'Ambassador',
#  'to',
#  'Canada',
#  'under',
#  'Joe',
#  'Biden,',
#  'David',
#  'L.',
#  'Cohen,',
#  'claimed',
#  'Canada’s',
#  'responses',
#  'to',
#  'Donald',
#  'Trump’s',
#  'tariffs',
#  'and',
#  'sovereignty',
#  'threats',
#  'were',
#  'an',
#  'overreaction',
#  'caused',
#  'by',
#  'the',
#  "President's",
#  'strained',
#  'relationship',
#  'with',
#  'Justin',
#  'Trudeau.']

# %%
split = text.split()
print(type(split))  #str list ma change vayo
# Out:
# <class 'list'>

# %%
text.upper()
# Out:
# "HE SUGGESTED TRUDEAU WAS THE PROBLEM\n@THE DAILY DIGEST\nON MAY 16TH, AN INTERESTING INTERVIEW WITH THE FORMER US AMBASSADOR TO CANADA UNDER JOE BIDEN, DAVID L. COHEN, CLAIMED CANADA’S RESPONSES TO DONALD TRUMP’S TARIFFS AND SOVEREIGNTY THREATS WERE AN OVERREACTION CAUSED BY THE PRESIDENT'S STRAINED RELATIONSHIP WITH JUSTIN TRUDEAU.\n"

# %%
text.lower()
# Out:
# "he suggested trudeau was the problem\n@the daily digest\non may 16th, an interesting interview with the former us ambassador to canada under joe biden, david l. cohen, claimed canada’s responses to donald trump’s tariffs and sovereignty threats were an overreaction caused by the president's strained relationship with justin trudeau.\n"

# %%
text.isupper()
# Out:
# False

# %%
text.islower()
# Out:
# False

# %%
text.find(Daily)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 text.find(Daily)
#
# NameError: name 'Daily' is not defined

# %%
#isalph() method: special charatere xa ki naii
test = "hello hi"

# %%
test.isalpha()
# Out:
# False

# %%
test.isdigit()  #digit ho ki haina
# Out:
# False

# %%
#startwith

# %%
#def func
#string
#lower, upper

xutai variable, type string, teslai func ko throygh le pathauxa, kei texrt diyo vane lowe, upper rakhne, tyo banayepaxi returen priny garnu paryo

# %%
def text(sen):
    lower = sen.lower()
    upper = sen.upper()
    return lower, upper
    
lower, upper = text("Hi, how are you, I'm fine.")
print(lower)
print(upper)
# Out:
# hi, how are you, i'm fine.
# HI, HOW ARE YOU, I'M FINE.
