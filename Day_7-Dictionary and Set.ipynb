# %% [raw]
# Data structure ko part is dictional
# value is mutable, key is same

# %% [raw]
# Unorderd collections of key value pair
# Key must be uunique and updatable, duplicate hunu vayena
# Value can any python object (string, float, int, etc)

# %%
# Method 1: Using the curly braces {}
empty_dict = {}

student = {       #student vanera dictionary ho
    "name": "Alice",
    "age": 21,
   
    "courses": ["Maths", "Physics"] #courses vitra list xa
}

print(student)
# Out:
# {'name': 'Alice', 'age': 21, 'courses': ['Maths', 'Physics']}

# %%
type(student)
# Out:
# dict

# %%
student["address"] = "Kathmandu, Nepal"     #[] le key taneko ho, append gareko, xaina vane add garya ho
student
# Out:
# {'name': 'Alice',
#  'age': 21,
#  'courses': ['Maths', 'Physics'],
#  'address': 'Kathmandu, Nepal'}

# %%
student.get("courses") #one method is this to get smth
# Out:
# ['Maths', 'Physics']

# %%
student["courses"]  #yo tarikale pani garna pauxa
# Out:
# ['Maths', 'Physics']

# %%
print(student["name"])
print(student.get("age"))
print(student.get("courses")[1])
# Out:
# Alice
# 21
# Physics

# %%
# Method 2: Using the dict() constructor
grades = dict([("Math", 90),("Physics", 85)])
grades
# Out:
# {'Math': 90, 'Physics': 85}

# %%
type(grades)
# Out:
# dict

# %%
dir(dict)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
employee = dict(
    name = "Bob",
    department = "HR",
    employee_id = 9876,
    years_of_service = 5
)

print(employee)
print(type(employee))
# Out:
# {'name': 'Bob', 'department': 'HR', 'employee_id': 9876, 'years_of_service': 5}
# <class 'dict'>

# %%
#get
employee.get("name")
# Out:
# 'Bob'

# %%
#items
employee.items()
# Out:
# dict_items([('name', 'Bob'), ('department', 'HR'), ('employee_id', 9876), ('years_of_service', 5)])

# %%
#keys
employee.keys()
# Out:
# dict_keys(['name', 'department', 'employee_id', 'years_of_service'])

# %%
help(dict)
# Out:
# Help on class dict in module builtins:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
#  |      for k, v in iterable:
#  |          d[k] = v
#  |  dict(**kwargs) -> new dictionary initialized with the name=value pairs
#  |      in the keyword argument list.  For example:  dict(one=1, two=2)
#  |
#  |  Methods defined here:
#  |
#  |  __contains__(self, key, /)
#  |      True if the dictionary has the specified key, else False.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
# ...

# %%
employee.fromkeys("name")  #value haru none vayo, yesma dict banako
# Out:
# {'n': None, 'a': None, 'm': None, 'e': None}

# %%
employee.values()
# Out:
# dict_values(['Bob', 'HR', 9876, 5])

# %%
employee.pop("employee_id")
# Out:
# 9876

# %%
employee.items()
# Out:
# dict_items([('name', 'Bob'), ('department', 'HR'), ('years_of_service', 5)])

# %%
employee.update({"name": "Supriya"})
print("After update() method: ", employee)
# Out:
# After update() method:  {'name': 'Supriya', 'department': 'HR', 'years_of_service': 5, 'salary': 2000000}

# %%
#add
employee["salary"] = 2000000
employee
# Out:
# {'name': 'Supriya',
#  'department': 'HR',
#  'years_of_service': 5,
#  'salary': 2000000}

# %%
# Method 1: Using the 'del' keyword
print("Employee dict before deletion:", employee)
del employee['years_of_service']
print("After deleting 'years_of_service':", employee)
# Out:
# Employee dict before deletion: {'name': 'Supriya', 'department': 'HR', 'years_of_service': 5, 'salary': 2000000}
# After deleting 'years_of_service': {'name': 'Supriya', 'department': 'HR', 'salary': 2000000}

# %%
# Method 2: Using the .pop() method
dept = employee.pop('department')
print(f"Removed department: {dept}")
print("Employee dict after pop:", employee)
# Out:
# Removed department: HR
# Employee dict after pop: {'name': 'Supriya', 'salary': 2000000}

# %%
employee.clear()
print("Employee dict after clear:", employee)
# Out:
# Employee dict after clear: {}

# %%
#Task get 22
student = {
    "Name" : "User",
    "Age": 20,
    "courses":{
        "Maths":36,
        "science":66,
        "others":[
            22,44,66
        ]
              }
}

# %%
gets = student.get("courses").get("others")[0]
print(gets)
# Out:
# 22

# %%
#yo dict lehne ramro ,methid haina
product = {
    101: "id",
    5.1: "Laptop",
    "price": 1200.50,
    True: "hdhhd"
}

for i in product.keys():
    print(f"key:{i}, values:{product[i]}")
# Out:
# key:101, values:id
# key:5.1, values:Laptop
# key:price, values:1200.5
# key:True, values:hdhhd

# %% [raw]
# .keys ki for loop layerea tanna payo keys haru

# %%
for k,v in employees.items()  # k is key and v is value (any name can be written)
# Out:
#   Cell In[80], line 1
#     for k,v in employees.items()  # k is key and v is value (any name can be written)
#                                   ^
# SyntaxError: expected ':'

# %%
print("Iterating over keys:")
for k in employee:
    print(f"  Key: {k}, Value: {employee[k]}")

#.item.value.keys loop ma rakhem vane k aauxa vanera rakhne
# Out:
# Iterating over keys:
#   Key: name, Value: Bob
#   Key: department, Value: HR
#   Key: employee_id, Value: 9876
#   Key: years_of_service, Value: 5

# %% [raw]
# empty dict banauna dict() matra use garda ni payo

# %% [markdown]
# ### 1. What are Sets?
#  Sets are unordered collections of unique, immutable elements.
# *   They do not store duplicate elements.
# *   Elements must be immutable (like keys in dictionaries).
# *   Sets themselves are mutable (you can add/remove elements).
# *   There is no concept of order or index.
# *   Very efficient for membership testing (`in`) and removing duplicates.

# %%
#pura set chai mutable ho vitra ko chai immutable

# %%
#set ma unique hunxa, so repeat hudaina
numbers = {1, 2, 3, 4, 4, 5, 2}
print(numbers)
# Out:
# {1, 2, 3, 4, 5}

# %%
dir(set)
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %%
colors_list = ["Green", "Yellow", "Red", "Green", "Blue", "Yellow", "Yellow", "Blue"]
colors_set = set(colors_list)
print(colors_set)
# Out:
# {'Red', 'Blue', 'Yellow', 'Green'}

# %%
type(colors_set)
# Out:
# set

# %%
colors_list = ["Green", "Yellow", "Red", "Green", "Blue", "Yellow", "Yellow", "Blue"]
type(colors_list)
# Out:
# list

# %%
colors_list = {"Green", "Yellow", "Red", "Green", "Blue", "Yellow", "Yellow", "Blue"}
type(colors_list)
# Out:
# set

# %%
chars_set = set("hello world")
print(chars_set)
# Out:
# {' ', 'e', 'r', 'd', 'l', 'w', 'o', 'h'}

# %%
colors_set.add("Purple")
colors_set
colors_set.add("Orange")
colors_set
# Out:
# {'Blue', 'Green', 'Orange', 'Purple', 'Red', 'Yellow'}

# %%
colors_set.remove("Yellow")
print("After removing yellow:", colors_set)
# Out:
# After removing yellow: {'Blue', 'Orange', 'Green', 'Purple', 'Red'}

# %%
popped_element = colors_set.pop()
print(f"Popped element: {popped_element}")
print("Set after pop:", colors_set)
# Out:
# Popped element: Blue
# Set after pop: {'Orange', 'Green', 'Purple', 'Red'}

# %%
set_a = {1,2,6,7,9,10}
set_b = {2,6,8,10,12}

# %%
# Operator: |
# Method: .union()
union_set_op = set_a | set_b
union_set_meth = set_a.union(set_b)

print(f"Union (|): {union_set_op}")
print(f"Union (method): {union_set_meth}")
# Out:
# Union (|): {1, 2, 6, 7, 8, 9, 10, 12}
# Union (method): {1, 2, 6, 7, 8, 9, 10, 12}

# %%
# Operator: &
# Method: .intersection()
intersect_set_op = set_a & set_b
intersect_set_meth = set_a.intersection(set_b)
print(f"Intersection (&): {intersect_set_op}")
print(f"Intersection (method): {intersect_set_meth}")
# Out:
# Intersection (&): {2, 10, 6}
# Intersection (method): {2, 10, 6}

# %% [markdown]
# ### Advanced Data Structures and File Handling
#  ** Topics:
#  * Nested data structures (lists of lists, dictionaries of lists)

# %%
#vitra vitra ko item

# %%
#Example 1
# Example 1: Grouping students by course
students_by_course = {
    'Computer Science': ['Alice', 'David'],
    'Mathematics': ['Bob'],
    'Physics': ['Charlie', 'Eve']
}

print("Students grouped by course:")
print(students_by_course)
# Out:
# Students grouped by course:
# {'Computer Science': ['Alice', 'David'], 'Mathematics': ['Bob'], 'Physics': ['Charlie', 'Eve']}

# %%
# Example 2: Storing multiple scores for each student
student_scores = {
    'Alice': [85, 90, 88],
    'Bob': [92, 89, 95],
    'Charlie': [78, 82, 80]
}

print("\nStudent scores:")
print(student_scores)
# Out:
# Student scores:
# {'Alice': [85, 90, 88], 'Bob': [92, 89, 95], 'Charlie': [78, 82, 80]}

# %%
#structure ma (gap rakhenra) lekhna khojya
Name="John"
age = 20

print(f"Name   : {Name:<20} Age: {age}")
print(f"Name   : {Name:<20} Age: {age}")
print(f"Adress : {Name:<20} Age: {age}")
# Out:
# Name   : John                 Age: 20
# Name   : John                 Age: 20
# Adress : John                 Age: 20
